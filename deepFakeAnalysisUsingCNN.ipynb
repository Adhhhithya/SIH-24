# %%
import numpy as np
import pickle
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
import cv2
import os

# %%
def load_images_from_folder(folder, label):
    images = []
    labels = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder, filename))
        if img is not None:
            img = cv2.resize(img, (224, 224))  # Resize images to 224x224 pixels
            images.append(img)
            labels.append(label)
    return images, labels

real_images, real_labels = load_images_from_folder('dataset/real', 0)
fake_images, fake_labels = load_images_from_folder('dataset/fake', 1)

# Combine real and fake data
images = np.array(real_images + fake_images)
labels = np.array(real_labels + fake_labels)

# %%
print(images)
# Out:
# [[[[ 80 174 189]
#    [ 78 175 189]
#    [ 80 175 192]
#    ...
#    [154 170 217]
#    [145 160 216]
#    [135 151 210]]
#
#   [[ 78 176 190]
#    [ 87 187 202]
#    [ 94 193 209]
#    ...
#    [139 152 207]
#    [130 141 201]
#    [125 137 198]]
#
#   [[ 95 196 211]
#    [ 96 200 214]
#    [ 98 200 218]
#    ...
#    [129 141 199]
#    [120 130 190]
#    [132 143 201]]
#
#   ...
#
#   [[122  86 106]
#    [119  87 104]
#    [120  94 108]
#    ...
#    [ 29  17  23]
#    [ 32  22  25]
#    [ 37  30  31]]
#
#   [[113  80 101]
#    [123  93 112]
#    [130 103 119]
#    ...
#    [ 28  14  18]
#    [ 33  22  25]
#    [ 31  23  24]]
#
#   [[109  80 103]
#    [115  87 107]
#    [124  96 115]
#    ...
#    [ 31  18  20]
#    [ 30  18  20]
#    [ 32  22  25]]]
#
#
#  [[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   ...
#
#   [[170 186 232]
#    [169 185 231]
#    [168 184 229]
#    ...
#    [161 177 221]
#    [168 184 222]
#    [171 186 219]]
#
#   [[166 182 230]
#    [166 181 229]
#    [167 183 230]
#    ...
#    [162 178 225]
#    [161 177 222]
#    [164 180 224]]
#
#   [[168 184 231]
#    [167 183 229]
#    [166 182 228]
#    ...
#    [159 177 223]
#    [157 175 222]
#    [157 174 223]]]
#
#
#  [[[ 39  43  38]
#    [ 33  36  32]
#    [ 30  34  29]
#    ...
#    [ 54  77  92]
#    [ 58  80  96]
#    [ 54  77  92]]
#
#   [[ 37  40  38]
#    [ 32  35  33]
#    [ 29  32  30]
#    ...
#    [ 50  73  89]
#    [ 55  77  92]
#    [ 51  75  89]]
#
#   [[ 35  38  36]
#    [ 32  35  33]
#    [ 27  30  28]
#    ...
#    [ 49  72  87]
#    [ 58  81  96]
#    [ 50  73  88]]
#
#   ...
#
#   [[ 29  30  28]
#    [ 29  30  29]
#    [ 29  29  28]
#    ...
#    [ 92  90  81]
#    [ 94  91  83]
#    [ 96  90  83]]
#
#   [[ 29  29  28]
#    [ 27  28  26]
#    [ 30  31  29]
#    ...
#    [111 109  99]
#    [106 101  93]
#    [ 99  93  86]]
#
#   [[ 31  32  30]
#    [ 29  30  28]
#    [ 25  26  24]
#    ...
#    [136 131 122]
#    [103  98  89]
#    [100  92  85]]]
#
#
#  ...
#
#
#  [[[221 218 213]
#    [215 212 206]
#    [221 218 212]
#    ...
#    [220 216 211]
#    [227 223 218]
#    [214 211 205]]
#
#   [[224 221 216]
#    [223 220 215]
#    [224 221 217]
#    ...
#    [225 221 216]
#    [229 225 220]
#    [219 215 210]]
#
#   [[231 228 223]
#    [218 215 210]
#    [226 223 218]
#    ...
#    [231 227 222]
#    [224 220 215]
#    [212 208 203]]
#
#   ...
#
#   [[214 212 203]
#    [196 194 184]
#    [177 176 166]
#    ...
#    [210 205 202]
#    [231 226 223]
#    [218 213 210]]
#
#   [[145 145 135]
#    [135 137 126]
#    [128 131 119]
#    ...
#    [228 223 220]
#    [211 206 203]
#    [216 211 208]]
#
#   [[141 145 139]
#    [145 149 143]
#    [151 157 148]
#    ...
#    [210 205 202]
#    [229 224 221]
#    [214 209 206]]]
#
#
#  [[[ 16  31   3]
#    [ 15  33   4]
#    [ 16  35   7]
#    ...
#    [  4  84 179]
#    [  1  80 175]
#    [  3  78 176]]
#
#   [[ 17  33   6]
#    [ 18  36  11]
#    [ 15  36  12]
#    ...
#    [  1  87 186]
#    [  4  85 185]
#    [  2  79 180]]
#
#   [[ 13  29   3]
#    [ 13  32   9]
#    [ 10  32  13]
#    ...
#    [  2  89 186]
#    [  2  83 182]
#    [  3  79 179]]
#
#   ...
#
#   [[ 42  60  71]
#    [ 46  63  71]
#    [ 49  67  73]
#    ...
#    [ 89 103 122]
#    [ 92 106 125]
#    [ 90 104 122]]
#
#   [[ 43  61  73]
#    [ 47  63  75]
#    [ 41  58  68]
#    ...
#    [ 94 108 127]
#    [ 91 105 124]
#    [ 95 109 129]]
#
#   [[ 39  58  65]
#    [ 46  63  72]
#    [ 44  60  69]
#    ...
#    [ 92 106 124]
#    [ 92 106 125]
#    [ 94 108 127]]]
#
#
#  [[[251 247 242]
#    [251 246 241]
#    [251 247 242]
#    ...
#    [254 248 243]
#    [254 248 243]
#    [253 248 242]]
#
#   [[252 248 242]
#    [251 247 242]
#    [252 248 243]
#    ...
#    [254 248 243]
#    [254 248 243]
#    [253 247 242]]
#
#   [[253 249 244]
#    [252 248 243]
#    [251 247 243]
#    ...
#    [253 247 242]
#    [253 247 242]
#    [255 249 244]]
#
#   ...
#
#   [[ 94 123 171]
#    [ 89 118 167]
#    [ 91 120 167]
#    ...
#    [ 74  77 231]
#    [151 136 230]
#    [253 251 243]]
#
#   [[101 127 171]
#    [ 93 123 168]
#    [ 89 121 172]
#    ...
#    [ 55  66 237]
#    [ 65  79 233]
#    [107  97 231]]
#
#   [[ 86 112 163]
#    [ 80 110 157]
#    [ 88 117 172]
#    ...
#    [ 52  65 232]
#    [ 55  61 236]
#    [ 66  76 235]]]]

# %%
x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)
x_train = x_train / 255.0  # Normalize pixel values
x_test = x_test / 255.0

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\Ajay\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.5460 - loss: 1.5159 - val_accuracy: 0.5330 - val_loss: 0.7050
# Epoch 2/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.5647 - loss: 0.6913 - val_accuracy: 0.5795 - val_loss: 0.6757
# Epoch 3/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.5964 - loss: 0.6642 - val_accuracy: 0.5990 - val_loss: 0.6592
# Epoch 4/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.6214 - loss: 0.6650 - val_accuracy: 0.6284 - val_loss: 0.6367
# Epoch 5/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.6828 - loss: 0.5963 - val_accuracy: 0.5868 - val_loss: 0.6828
# Epoch 6/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7375 - loss: 0.5159 - val_accuracy: 0.5575 - val_loss: 0.7729
# Epoch 7/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.7782 - loss: 0.4430 - val_accuracy: 0.5428 - val_loss: 0.7921
# Epoch 8/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.8615 - loss: 0.3171 - val_accuracy: 0.5501 - val_loss: 1.0412
# Epoch 9/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9100 - loss: 0.2079 - val_accuracy: 0.5428 - val_loss: 1.5830
# Epoch 10/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.9653 - loss: 0.1011 - val_accuracy: 0.5257 - val_loss: 1.8397

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 346ms/step - accuracy: 0.4760 - loss: 2.0312
# Test Accuracy: 52.57%

# %%
real_images, real_labels = load_images_from_folder('testdata/real', 0)
fake_images, fake_labels = load_images_from_folder('testdata/fake', 1)

# %%
images = np.array(real_images + fake_images)
labels = np.array(real_labels + fake_labels)
len(images)
# Out:
# 2041

# %%
model.predict(images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.predict(images)
#
# NameError: name 'model' is not defined

# %%
loss,accuracy = model.evaluate(images,labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 loss,accuracy = model.evaluate(images,labels)
#
# NameError: name 'model' is not defined

# %%
with open('model.pickle','rb') as file:
    m = pickle.load(file)
loss,accuracy = m.evaluate(images,labels)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.9067 - loss: 136.6563
